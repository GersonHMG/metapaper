# %% [markdown]
# This notebook is to check if the dataloader its working

# %% [markdown]
# # Data Loader Tests

# %% [markdown]
# In this section we test the dataloader, we need to know if:
#
# 1. Data is loaded correctly
# 2. Data is split correctly

# %%
from datasets.data_loader import load_patient_data

# %%
X, y = load_patient_data("chb01", only_seizure_files=True)
# Out:
# Loading chb01: 100%|██████████| 7/7 [00:00<00:00,  7.42file/s]

# %%
X[0]
# Out:
# array([57.24053724, 53.33333333, 45.90964591, ..., 47.08180708,
#        -9.18192918, 28.71794872], shape=(215040,))
